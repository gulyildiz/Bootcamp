# %% [markdown]
# #Jupyter notebook ile phyton programlama

# %% [markdown]
# #Notebook kullanımı ve phyton diline giriş yapılacaktır.

# %% [markdown]
# ![image.png](attachment:f8e9d5d8-80db-4b3a-a10f-367554ca1fa3.png)

# %% [markdown]
# #başlık1

# %% [markdown]
# ##başlık2

# %% [markdown]
# ###başlık3

# %% [markdown]
# ####başlık4

# %% [markdown]
# #Metin biçimlendirme
# **bold**
# *italik*
# [google]: Link vermek için [] başlayıp sonrasında () bu parantezle linkin devamını yazman gerekiyor.

# %% [markdown]
# 1. Ceren
# 2. İrem
# 😊👌👌👌👌
#
# > blok
# >
# > blok sonu
# >

# %% [markdown]
# #Latex kullanımı

# %% [markdown]
# $$c=\sqrt{a*2+b^2}$$

# %% [markdown]
# from IPython.display import display, Math, Latex
# display(Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx'))

# %% [markdown]
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %% [markdown]
# #komut satırı işlemleri

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4C16-0290
#
#  Directory of C:\Users\gulcy\Documents\Bootcamp\day2
#
# 01.08.2024  22:47    <DIR>          .
# 01.08.2024  21:48    <DIR>          ..
# 01.08.2024  21:53    <DIR>          .ipynb_checkpoints
# 01.08.2024  22:47            43.488 Jupyter-Phyton.ipynb
#                1 File(s)         43.488 bytes
#                3 Dir(s)  399.189.557.248 bytes free

# %% [markdown]
# #Kütüphane kurulumu

# %%
#Aşağıdaki kütüphaneyi kurmak için # işareti kaldırıp yorum satırından çıkartman gerekiyor.

# %%
#pip install pycaret

# %% [markdown]
# #Colab simgesi ekle

# %% [markdown]
# #Eğer yaptığın bir çalışmayı eklemek istiyorsan/sadece görüntülenmesini istiyorsan linki eklemen gerekiyor. Sadece o anlık halini alır yapılan değişiklikleri değiştirip göstermez.

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eladrich/pixel2style2pixel/blob/master/notebooks/inference_playground.ipynb)

# %% [markdown]
# [![My GitHub Profile](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSQpRbN3ODAty8IkRiV0HtLrscbJWy5ubgYLw&s)](https://github.com/gulyildiz)

# %% [markdown]
# #Raw yaparsan olduğu gibi bırakır dönüştürmez.

# %% [raw]
# $\alpha$, $\beta$, $\gamma$

# %% [markdown]
# [![My GitHub Profile](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQAPAp2LhRFQ0ZDueTfeXZqqYn6GWxdecHHcg&s)](https://github.com/gulyildiz)
